# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# This is just to make plots appear in the notebook
# %matplotlib inline
pd.set_option('display.max_columns', None)
from src.data_processing.datframe_manipulation import (
    load_data, split_features_n_labels,
)

from src.data_processing.dataframe_preprocessing import (
    scale_features,
)

# %% [markdown]
# Load data

# %%
# Load the data
df = load_data()

# Create features and labels dfs.
(
features,
labels
)= split_features_n_labels(df)

# %%
# Check the correlation
# Create a correlation matrix
corr_metrics = df.corr()
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_fae41_row0_col0, #T_fae41_row1_col1, #T_fae41_row2_col2, #T_fae41_row3_col3, #T_fae41_row4_col4, #T_fae41_row5_col5, #T_fae41_row6_col6, #T_fae41_row7_col7, #T_fae41_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fae41_row0_col1, #T_fae41_row1_col0, #T_fae41_row1_col3, #T_fae41_row2_col5, #T_fae41_row2_col7, #T_fae41_row4_col2, #T_fae41_row4_col6, #T_fae41_row4_col8, #T_fae41_row6_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fae41_row0_col2 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_fae41_row0_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_fae41_row0_col4 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_fae41_row0_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_fae41_row0_col6, #T_fae41_row8_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_fae41_row0_col7, #T_fae41_row1_col7 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_fae41_row0_col8, #T_fae41_row3_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_fae41_row1_col2 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_fae41_row1_col4, #T_fae41_row4_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_fae41_row1_col5, #T_fae41_row2_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_fae41_row1_col6, #T_fae41_row6_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_fae41_row1_col8 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_fae41_row2_col0, #T_fae41_row5_col0, #T_fae41_row5_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_fae41_row2_col1, #T_fae41_row6_col0, #T_fae41_row7_col0, #T_fae41_row7_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_fae41_row2_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_fae41_row2_col6 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_fae41_row2_col8 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_fae41_row3_col0, #T_fae41_row7_col3 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_fae41_row3_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_fae41_row3_col2, #T_fae41_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_fae41_row3_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_fae41_row3_col5, #T_fae41_row5_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_fae41_row3_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_fae41_row3_col8, #T_fae41_row4_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_fae41_row4_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_fae41_row4_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_fae41_row4_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fae41_row5_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_fae41_row5_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_fae41_row5_col4, #T_fae41_row6_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_fae41_row5_col6 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_fae41_row5_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_fae41_row6_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_fae41_row6_col3, #T_fae41_row6_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_fae41_row6_col8 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_fae41_row7_col4 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_fae41_row7_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_fae41_row7_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_fae41_row7_col8 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_fae41_row8_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_fae41_row8_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_fae41_row8_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_fae41_row8_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_fae41_row8_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_fae41_row8_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_fae41_row8_col7 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_fae41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fae41_level0_col0" class="col_heading level0 col0" >track_id</th>
#       <th id="T_fae41_level0_col1" class="col_heading level0 col1" >acousticness</th>
#       <th id="T_fae41_level0_col2" class="col_heading level0 col2" >danceability</th>
#       <th id="T_fae41_level0_col3" class="col_heading level0 col3" >energy</th>
#       <th id="T_fae41_level0_col4" class="col_heading level0 col4" >instrumentalness</th>
#       <th id="T_fae41_level0_col5" class="col_heading level0 col5" >liveness</th>
#       <th id="T_fae41_level0_col6" class="col_heading level0 col6" >speechiness</th>
#       <th id="T_fae41_level0_col7" class="col_heading level0 col7" >tempo</th>
#       <th id="T_fae41_level0_col8" class="col_heading level0 col8" >valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fae41_level0_row0" class="row_heading level0 row0" >track_id</th>
#       <td id="T_fae41_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_fae41_row0_col1" class="data row0 col1" >-0.372282</td>
#       <td id="T_fae41_row0_col2" class="data row0 col2" >0.049454</td>
#       <td id="T_fae41_row0_col3" class="data row0 col3" >0.140703</td>
#       <td id="T_fae41_row0_col4" class="data row0 col4" >-0.275623</td>
#       <td id="T_fae41_row0_col5" class="data row0 col5" >0.048231</td>
#       <td id="T_fae41_row0_col6" class="data row0 col6" >-0.026995</td>
#       <td id="T_fae41_row0_col7" class="data row0 col7" >-0.025392</td>
#       <td id="T_fae41_row0_col8" class="data row0 col8" >0.010070</td>
#     </tr>
#     <tr>
#       <th id="T_fae41_level0_row1" class="row_heading level0 row1" >acousticness</th>
#       <td id="T_fae41_row1_col0" class="data row1 col0" >-0.372282</td>
#       <td id="T_fae41_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_fae41_row1_col2" class="data row1 col2" >-0.028954</td>
#       <td id="T_fae41_row1_col3" class="data row1 col3" >-0.281619</td>
#       <td id="T_fae41_row1_col4" class="data row1 col4" >0.194780</td>
#       <td id="T_fae41_row1_col5" class="data row1 col5" >-0.019991</td>
#       <td id="T_fae41_row1_col6" class="data row1 col6" >0.072204</td>
#       <td id="T_fae41_row1_col7" class="data row1 col7" >-0.026310</td>
#       <td id="T_fae41_row1_col8" class="data row1 col8" >-0.013841</td>
#     </tr>
#     <tr>
#       <th id="T_fae41_level0_row2" class="row_heading level0 row2" >danceability</th>
#       <td id="T_fae41_row2_col0" class="data row2 col0" >0.049454</td>
#       <td id="T_fae41_row2_col1" class="data row2 col1" >-0.028954</td>
#       <td id="T_fae41_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_fae41_row2_col3" class="data row2 col3" >-0.242032</td>
#       <td id="T_fae41_row2_col4" class="data row2 col4" >-0.255217</td>
#       <td id="T_fae41_row2_col5" class="data row2 col5" >-0.106584</td>
#       <td id="T_fae41_row2_col6" class="data row2 col6" >0.276206</td>
#       <td id="T_fae41_row2_col7" class="data row2 col7" >-0.242089</td>
#       <td id="T_fae41_row2_col8" class="data row2 col8" >0.473165</td>
#     </tr>
#     <tr>
#       <th id="T_fae41_level0_row3" class="row_heading level0 row3" >energy</th>
#       <td id="T_fae41_row3_col0" class="data row3 col0" >0.140703</td>
#       <td id="T_fae41_row3_col1" class="data row3 col1" >-0.281619</td>
#       <td id="T_fae41_row3_col2" class="data row3 col2" >-0.242032</td>
#       <td id="T_fae41_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_fae41_row3_col4" class="data row3 col4" >0.028238</td>
#       <td id="T_fae41_row3_col5" class="data row3 col5" >0.113331</td>
#       <td id="T_fae41_row3_col6" class="data row3 col6" >-0.109983</td>
#       <td id="T_fae41_row3_col7" class="data row3 col7" >0.195227</td>
#       <td id="T_fae41_row3_col8" class="data row3 col8" >0.038603</td>
#     </tr>
#     <tr>
#       <th id="T_fae41_level0_row4" class="row_heading level0 row4" >instrumentalness</th

# %% [markdown]
# Scale the features dataframe

# %%
scaled_train_features = scale_features(features)
